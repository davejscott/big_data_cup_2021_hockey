# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import time
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import GradientBoostingClassifier
plt.rcParams['figure.figsize'] = [20, 10]

# %%
df = pd.read_csv('hackathon_nwhl.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-98d4fadead3d> in <module>()
# ----> 1 df = pd.read_csv('hackathon_nwhl.csv')
#
# /Users/davescott/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
def change_clock_time(clock_time):
    """
    take str clock
    format and return as time in seconds
    *** will update later to include period, didn't do now to avoid
    issues with added time in overtime
    """
    x = time.strptime(clock_time.split(',')[0],'%M:%S')
    time_in_seconds = datetime.timedelta(hours=x.tm_hour,minutes=x.tm_min,seconds=x.tm_sec).total_seconds()
    return time_in_seconds

# %% [markdown]
# ### For example

# %%
change_clock_time(df['Clock'][66])
# Out:
# 1066.0

# %%
df.Clock = df.Clock.transform(change_clock_time)

# %%
df.head()
# Out:
#     game_date            Home Team     Away Team  Period   Clock  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1200.0
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1198.0
# 2  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1197.0
# 3  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1195.0
# 4  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1193.0
#
#    Home Team Skaters  Away Team Skaters  Home Team Goals  Away Team Goals  \
# 0                  5                  5                0                0
# 1                  5                  5                0                0
# 2                  5                  5                0                0
# 3                  5                  5                0                0
# 4                  5                  5                0                0
#
#            Team  ...          Event X Coordinate  Y Coordinate  Detail 1  \
# ...

# %%
print(df.shape)
df.describe()
# Out:
# (26882, 21)
#              Period         Clock  Home Team Skaters  Away Team Skaters  \
# count  26882.000000  26882.000000       26882.000000       26882.000000
# mean       2.010565    604.333643           4.867086           4.866491
# std        0.834753    348.735998           0.357216           0.376766
# min        1.000000      0.000000           3.000000           3.000000
# 25%        1.000000    302.000000           5.000000           5.000000
# 50%        2.000000    605.500000           5.000000           5.000000
# 75%        3.000000    908.000000           5.000000           5.000000
# max        4.000000   1200.000000           6.000000           6.000000
#
#        Home Team Goals  Away Team Goals  X Coordinate  Y Coordinate  \
# count     26882.000000     26882.000000  26882.000000  26882.000000
# mean          1.408005         0.998847     97.396771     42.192768
# std           1.598554         1.292165     63.188185     27.983077
# ...

# %%
df.columns
# Out:
# Index(['game_date', 'Home Team', 'Away Team', 'Period', 'Clock',
#        'Home Team Skaters', 'Away Team Skaters', 'Home Team Goals',
#        'Away Team Goals', 'Team', 'Player', 'Event', 'X Coordinate',
#        'Y Coordinate', 'Detail 1', 'Detail 2', 'Detail 3', 'Detail 4',
#        'Player 2', 'X Coordinate 2', 'Y Coordinate 2'],
#       dtype='object')

# %% [markdown]
# ## Can unhash to see the type of datatypes and how many empty dataframe values.

# %% [markdown]
# df.dtypes

# %% [markdown]
# df.isna().sum(0)

# %%
len(df['Player'].unique())
# Out:
# 126

# %%
for col in df:
    print("The unique items in", col.capitalize(), len(df[col].unique()))
# Out:
# The unique items in Game_date 7
# The unique items in Home team 6
# The unique items in Away team 6
# The unique items in Period 4
# The unique items in Clock 1201
# The unique items in Home team skaters 4
# The unique items in Away team skaters 4
# The unique items in Home team goals 7
# The unique items in Away team goals 8
# The unique items in Team 6
# The unique items in Player 126
# The unique items in Event 10
# The unique items in X coordinate 201
# The unique items in Y coordinate 86
# The unique items in Detail 1 34
# The unique items in Detail 2 4
# The unique items in Detail 3 3
# The unique items in Detail 4 3
# The unique items in Player 2 118
# The unique items in X coordinate 2 202
# The unique items in Y coordinate 2 87

# %%
plays_of_interest = ['Shot', 'Play', 'Goal']

# %%
df.Event.head(3)
# Out:
# 0      Faceoff Win
# 1    Puck Recovery
# 2       Zone Entry
# Name: Event, dtype: object

# %% [markdown]
# ## Create a filtered dataframe that only contains passes (Play), Shots (Shot), and Goals(Goal)

# %%
df_filter_plays = pd.concat([pd.concat([df.loc[df.Event == 'Play'], df.loc[df.Event == 'Shot']], axis=0), df.loc[df.Event == 'Goal']], axis = 0)
df_filter_plays.head(5)
# Out:
#      game_date            Home Team     Away Team  Period   Clock  \
# 8   2021-01-23  Minnesota Whitecaps  Boston Pride       1  1187.0
# 9   2021-01-23  Minnesota Whitecaps  Boston Pride       1  1183.0
# 11  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1180.0
# 17  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1168.0
# 22  2021-01-23  Minnesota Whitecaps  Boston Pride       1  1157.0
#
#     Home Team Skaters  Away Team Skaters  Home Team Goals  Away Team Goals  \
# 8                   5                  5                0                0
# 9                   5                  5                0                0
# 11                  5                  5                0                0
# 17                  5                  5                0                0
# 22                  5                  5                0                0
#
#                    Team  ... Event X Coordinate  Y Coordinate  Detail 1  \
# ...

# %%
df_filter_plays.columns
# Out:
# Index(['game_date', 'Home Team', 'Away Team', 'Period', 'Clock',
#        'Home Team Skaters', 'Away Team Skaters', 'Home Team Goals',
#        'Away Team Goals', 'Team', 'Player', 'Event', 'X Coordinate',
#        'Y Coordinate', 'Detail 1', 'Detail 2', 'Detail 3', 'Detail 4',
#        'Player 2', 'X Coordinate 2', 'Y Coordinate 2'],
#       dtype='object')

# %%
filter_df_columns = [x for x in df.columns]
filter_df_columns.append('Time Between Shot')
filter_df_columns.append('Previous Pass Index')

# %% [markdown]
# # Using this to create a stream where we look on a play where
# ## a puck has been accepted by the original action (pass) which is Player 2 then it is shot by Player 2 of the pass (who is now Player) in the secondary action
# ## action: is the original action (right now looking for pass)
# ## action_filtered is the secondary action (right now is a shot or goal)
# ## The goal of this filtering is to create a dataframe where a player has accepted a pass and then is shot or scores a goal within 30 seconds of recieving that pass.
# ## We also track the time between shot and receiving pass, as well as the previous index of that pass

# %%
new_data = pd.DataFrame(columns = filter_df_columns)
for og_index, action in df_filter_plays.iterrows():
    if action['Event'] == "Play":
        print(og_index)
        for index_filtered, action_filtered in df_filter_plays.iterrows():
            if index_filtered < og_index:
                continue
            else:
                time_difference = action['Clock'] - action_filtered['Clock'] 
                if time_difference > 30:
                    break
                if action_filtered['Player'] == action['Player 2']:
                    if action_filtered['Event'] == 'Shot' or action_filtered['Event'] == 'Goal':
                        action_to_append = action_filtered.append(pd.Series(time_difference, index=['Time Between Shot']))
                        action_to_append = action_to_append.append(pd.Series(og_index, index = ['Previous Pass Index']))
                        new_data = new_data.append(pd.DataFrame(action_to_append).T)
                        break
                    else:
                        continue
    else:
        continue
    if og_index > 5000:
        break
# Out:
# 8
# 9
# 11
# 17
# 22
# 25
# 26
# 28
# 31
# 35
# 36
# 37
# 40
# 42
# 51
# 56
# 58
# 59
# 67
# 68
# 69
# 74
# 77
# 83
# 84
# 85
# 86
# 89
# 92
# 99
# 100
# 101
# 104
# 105
# 106
# 112
# 113
# 117
# 126
# 137
# 142
# 156
# 158
# 164
# 165
# 166
# 174
# 175
# 178
# 180
# 190
# 194
# 195
# 198
# 201
# 202
# 213
# 214
# 215
# 218
# 220
# 222
# 227
# 228
# 241
# 245
# 246
# 247
# 248
# 249
# 252
# 259
# 268
# 269
# 285
# 291
# 298
# 303
# 304
# 305
# 312
# 320
# 326
# 327
# 338
# 339
# 343
# 350
# 353
# 358
# 371
# 380
# 390
# 396
# 397
# 403
# 405
# 408
# 409
# 428
# 433
# 434
# 451
# 453
# 465
# 470
# 471
# 476
# 479
# 485
# 487
# 488
# 492
# 493
# 494
# 506
# 508
# 509
# 510
# 511
# 512
# 515
# 524
# 530
# 535
# 536
# 540
# 549
# 552
# 553
# 554
# 562
# 563
# 569
# 570
# 571
# 577
# 578
# 584
# 589
# 592
# 599
# 600
# 604
# 605
# 606
# 609
# 613
# 617
# 620
# 621
# 635
# 641
# 647
# 648
# 650
# 656
# 657
# 662
# 665
# 669
# 670
# 671
# 679
# 686
# 687
# 695
# 699
# 702
# 708
# 709
# 710
# ...

# %%
new_data
# Out:
#     game_date              Home Team              Away Team Period Clock  \
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3   763
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      2  1118
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      2   528
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3   979
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3  1138
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3  1134
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3  1138
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3   979
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3  1138
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3  1134
# 0  2021-01-23    Minnesota Whitecaps           Boston Pride      3  1003
# 0  2021-01-24           Boston Pride         Buffalo Beauts      1  1071
# ...

# %%
df_filter_plays.loc[4780]
# Out:
# game_date                       2021-01-23
# Home Team            Metropolitan Riveters
# Away Team                      Toronto Six
# Period                                   2
# Clock                                    4
# Home Team Skaters                        5
# Away Team Skaters                        5
# Home Team Goals                          2
# Away Team Goals                          0
# Team                 Metropolitan Riveters
# Player                      Sammy Kolowrat
# Event                                 Play
# X Coordinate                             3
# Y Coordinate                            46
# Detail 1                            Direct
# Detail 2                               NaN
# Detail 3                               NaN
# Detail 4                               NaN
# Player 2                       Jayne Lewis
# X Coordinate 2                          14
# Y Coordinate 2                          79
# Name: 4780, dtype: object

# %% [markdown]
# # Data uploaded on February 23 by Bill

# %%
df = pd.read_csv('data_2020-02-23.csv')

# %%
df.head()
# Out:
#     game_date            home_team     away_team  period  game_seconds  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1            53
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1            86
# 2  2021-01-23  Minnesota Whitecaps  Boston Pride       1           190
# 3  2021-01-23  Minnesota Whitecaps  Boston Pride       1           222
# 4  2021-01-23  Minnesota Whitecaps  Boston Pride       1           244
#
#    time_since_pass  home_team_skaters  away_team_skaters  home_team_goals  \
# 0                1                  5                  5                0
# 1                2                  5                  5                0
# 2                0                  5                  5                0
# 3                1                  5                  5                0
# 4                4                  5                  5                0
#
#    away_team_goals  ... pass_y rec_x rec_y          shooter  shot_x  shot_y  \
# ...

# %%
df.columns
# Out:
# Index(['game_date', 'home_team', 'away_team', 'period', 'game_seconds',
#        'time_since_pass', 'home_team_skaters', 'away_team_skaters',
#        'home_team_goals', 'away_team_goals', 'team', 'event', 'passer',
#        'pass_type', 'pass_x', 'pass_y', 'rec_x', 'rec_y', 'shooter', 'shot_x',
#        'shot_y', 'shot_type', 'shot_outcome', 'shot_traffic', 'shot_onetimer'],
#       dtype='object')

# %% [markdown]
# ## New columns bill has added are above, also some renaming of columns.

# %%
df.shape
# Out:
# (1197, 25)

# %% [markdown]
# # Pass Locations

# %%
plt.scatter(df.pass_x[0:400], df.pass_y[0:400])
plt.xlabel('Rink position length(ft)')
plt.ylabel('Rink position width(ft)')
plt.show()

# %%
plt.scatter(df.rec_x[0:400], df.rec_y[0:400])
plt.xlabel('Rink position length(ft)')
plt.ylabel('Rink position width(ft)')
plt.show()

# %% [markdown]
# ## Shot locations

# %%
plt.scatter(df.shot_x[0:1000], df.shot_y[0:1000])
plt.xlabel('Rink position length(ft)')
plt.ylabel('Rink position width(ft)')
plt.show()

# %% [markdown]
# ## Calculate distance between pass to reception between shot to net

# %%
def distance_btwn_pass_recipient(row):
    """
    take x and y coordinate of shot
    calculate euclidean distance between this 
    and the shot location
    """
    pass_x, pass_y = row['pass_x'], row['pass_y']
    recp_x, recp_y = row['rec_x'], row['rec_y']
    euclidean_dist = math.sqrt((recp_x - pass_x) ** 2 + (recp_y - pass_y) ** 2)
    return euclidean_dist

# %%
df['pass_to_recp_distance'] = df.apply(distance_btwn_pass_recipient, axis=1)

# %%
df.head(2)
# Out:
#     game_date            home_team     away_team  period  game_seconds  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1            53
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1            86
#
#    time_since_pass  home_team_skaters  away_team_skaters  home_team_goals  \
# 0                1                  5                  5                0
# 1                2                  5                  5                0
#
#    away_team_goals  ... rec_x rec_y        shooter shot_x  shot_y  shot_type  \
# 0                0  ...   161    14   Nina Rodgers    167      18   Snapshot
# 1                0  ...   168    74  McKenna Brand    175      68   Snapshot
#
#    shot_outcome  shot_traffic shot_onetimer  pass_to_recp_distance
# 0        Missed         False         False               8.062258
# 1        On Net         False         False              39.661064
#
# [2 rows x 26 columns]

# %% [markdown]
# ## Distance between reception and shot

# %%
def distance_btwn_recpient_shot(row):
    """
    take x and y coordinate of shot
    calculate euclidean distance between this 
    and the shot location
    """
    recp_x, recp_y = row['rec_x'], row['rec_y']
    shot_x, shot_y = row['shot_x'], row['shot_y']
    euclidean_dist = math.sqrt((shot_x - recp_x) ** 2 + (shot_y - recp_y) ** 2)
    return euclidean_dist

# %%
df['recp_to_shot_distance'] = df.apply(distance_btwn_recpient_shot, axis=1)

# %%
df.head(2)
# Out:
#     game_date            home_team     away_team  period  game_seconds  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1            53
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1            86
#
#    time_since_pass  home_team_skaters  away_team_skaters  home_team_goals  \
# 0                1                  5                  5                0
# 1                2                  5                  5                0
#
#    away_team_goals  ... rec_y        shooter shot_x shot_y  shot_type  \
# 0                0  ...    14   Nina Rodgers    167     18   Snapshot
# 1                0  ...    74  McKenna Brand    175     68   Snapshot
#
#    shot_outcome  shot_traffic  shot_onetimer pass_to_recp_distance  \
# 0        Missed         False          False              8.062258
# 1        On Net         False          False             39.661064
#
#    recp_to_shot_distance
# 0               7.211103
# 1               9.219544
#
# [2 rows x 27 columns]

# %% [markdown]
# # Graph some statistics

# %%
df['shot_outcome'][:30]
# Out:
# 0      Missed
# 1      On Net
# 2      On Net
# 3      On Net
# 4      On Net
# 5      Missed
# 6      On Net
# 7      Missed
# 8      On Net
# 9      On Net
# 10     On Net
# 11     On Net
# 12    Blocked
# 13     Missed
# 14     Missed
# 15    Blocked
# 16     Missed
# 17     On Net
# 18    Blocked
# 19    Blocked
# 20     On Net
# 21     Missed
# 22    Blocked
# 23     On Net
# 24    Blocked
# 25     On Net
# 26    Blocked
# 27     On Net
# 28    Blocked
# 29     Missed
# Name: shot_outcome, dtype: object

# %%
plt.scatter(df.pass_to_recp_distance[0:30], df.recp_to_shot_distance[0:30])
plt.xlabel('Pass to Reception length(ft)')
plt.ylabel('Recp to Shot length (ft)')
plt.show()

# %%
plt.scatter(df.pass_to_recp_distance[0:30], df.recp_to_shot_distance[0:30])

for i, txt in enumerate(df['shot_outcome']):
    plt.annotate(txt, (df.pass_to_recp_distance[i], df.recp_to_shot_distance[i]))
    if i > 30:
        break

# %%
df.to_csv('data_2020_02_03_v2.csv', index=False,
          compression=compression_opts)

# %% [markdown]
# # Updates from bill making changes on the dataframe (morning)

# %%
df = pd.read_csv('data_2020-02-24.csv')

# %%
df.head()
# Out:
#     game_date            home_team     away_team  period  game_seconds  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1            53
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1            86
# 2  2021-01-23  Minnesota Whitecaps  Boston Pride       1           190
# 3  2021-01-23  Minnesota Whitecaps  Boston Pride       1           222
# 4  2021-01-23  Minnesota Whitecaps  Boston Pride       1           244
#
#    time_since_pass  home_team_skaters  away_team_skaters  home_team_goals  \
# 0                1                  5                  5                0
# 1                2                  5                  5                0
# 2                0                  5                  5                0
# 3                1                  5                  5                0
# 4                4                  5                  5                0
#
#    away_team_goals  ...          shooter shot_x shot_y shot_type  \
# ...

# %%
plt.scatter(df.pass_x[0:400], df.pass_y[0:400])
plt.xlabel('Rink position length(ft)')
plt.ylabel('Rink position width(ft)')
plt.show()

# %%
df.columns
# Out:
# Index(['game_date', 'home_team', 'away_team', 'period', 'game_seconds',
#        'time_since_pass', 'home_team_skaters', 'away_team_skaters',
#        'home_team_goals', 'away_team_goals', 'team', 'event', 'passer',
#        'pass_type', 'pass_x', 'pass_y', 'rec_x', 'rec_y', 'shooter', 'shot_x',
#        'shot_y', 'shot_type', 'shot_outcome', 'shot_traffic', 'shot_onetimer',
#        'pass_dist', 'shooter_dist', 'shot_dist'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
df['time_since_pass'].value_counts().plot(ax=ax, kind='bar')
plt.xlabel('Time since pass (s)')
plt.ylabel('Frequency of Occurence')
# Out:
# Text(0, 0.5, 'Frequency of Occurence')

# %% [markdown]
# ## INVESTIGATING WHAT RELATIONSHIPS MIGHT RESULT IN GOALS / HIGH QUALITY SHOTS

# %%
#plt.scatter(df.pass_dist[0:1000], df.shooter_dist[0:1000])

for i, txt in enumerate(df['shot_outcome']):
    if df['event'][i] == 'Goal':
        plt.scatter(df.pass_dist[i], df.shooter_dist[i])
        plt.annotate(txt, (df.pass_dist[i], df.shooter_dist[i]))

# %%
for i, txt in enumerate(df['shot_outcome']):
    if df['event'][i] == 'Goal':
        plt.scatter(df.pass_dist[i], df.shooter_dist[i])
        plt.annotate(txt, (df.pass_dist[i], df.shooter_dist[i]))

# %%
plt.scatter(df.pass_dist[0:250], df.shooter_dist[0:250])
for i, txt in enumerate(df['shot_outcome']):
    if df['event'][i] == 'Goal':
        plt.scatter(df.pass_dist[i], df.shooter_dist[i])
        plt.annotate(txt, (df.pass_dist[i], df.shooter_dist[i]))
    if i >250:
        break

# %%
for i, txt in enumerate(df['shot_outcome']):
    if df['event'][i] == 'Goal':
        plt.scatter(df.pass_dist[i], df.time_since_pass[i])
        plt.annotate(txt, (df.pass_dist[i], df.time_since_pass[i]))

# %%
plt.scatter(df.pass_dist[0:500], df.time_since_pass[0:500])
for i, txt in enumerate(df['shot_outcome']):
    if df['event'][i] == 'Goal':
        plt.scatter(df.shooter_dist[i], df.time_since_pass[i])
        plt.annotate(txt, (df.shooter_dist[i], df.time_since_pass[i]))
    if i >500:
        break
plt.xlabel('Shot Distance (from net)')
plt.ylabel('Time since pass (s)')
# Out:
# Text(0, 0.5, 'Time since pass (s)')

# %% [markdown]
# # Updates from bill making changes on the dataframe (afternoon)

# %%
import pandas as pd

# %%
df = pd.read_csv('data_2020-02-24.csv')

# %%
df.head()
# Out:
#     game_date            home_team     away_team  period  game_seconds  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1            53
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1            86
# 2  2021-01-23  Minnesota Whitecaps  Boston Pride       1           190
# 3  2021-01-23  Minnesota Whitecaps  Boston Pride       1           222
# 4  2021-01-23  Minnesota Whitecaps  Boston Pride       1           316
#
#    time_since_pass  home_team_goals  away_team_goals                 team  \
# 0                1                0                0  Minnesota Whitecaps
# 1                2                0                0         Boston Pride
# 2                0                0                0  Minnesota Whitecaps
# 3                1                0                0         Boston Pride
# 4                2                0                0         Boston Pride
#
#   game_state  ... shot_y shot_type  shot_outcome  shot_traffic  shot_onetimer  \
# ...

# %%
df.columns
# Out:
# Index(['game_date', 'home_team', 'away_team', 'period', 'game_seconds',
#        'time_since_pass', 'home_team_goals', 'away_team_goals', 'team',
#        'game_state', 'passer', 'shooter', 'pass_x', 'pass_y', 'rec_x', 'rec_y',
#        'shot_x', 'shot_y', 'shot_type', 'shot_outcome', 'shot_traffic',
#        'shot_onetimer', 'pass_dist', 'pass_angle', 'shooter_dist', 'shot_dist',
#        'shot_angle'],
#       dtype='object')

# %%
for i, txt in enumerate(df['shot_outcome']):
    if df['shot_outcome'][i] == 'Goal':
        plt.scatter(df.pass_dist[i], df.time_since_pass[i])
        plt.annotate(txt, (df.pass_dist[i], df.time_since_pass[i]))

# %%
plt.scatter(df.pass_dist[0:300], df.time_since_pass[0:300])
for i, txt in enumerate(df['shot_outcome']):
    if df['shot_outcome'][i] == 'Goal':
        plt.scatter(df.shooter_dist[i], df.time_since_pass[i])
        plt.annotate(txt, (df.shooter_dist[i], df.time_since_pass[i]))
    if i >500:
        break
plt.xlabel('Shot Distance (from net)')
plt.ylabel('Time since pass (s)')
# Out:
# Text(0, 0.5, 'Time since pass (s)')

# %%
fig, ax = plt.subplots()
df['time_since_pass'].value_counts().plot(ax=ax, kind='bar')
plt.xlabel('Time since pass (s)')
plt.ylabel('Frequency of Occurence')
# Out:
# Text(0, 0.5, 'Frequency of Occurence')

# %%
filter_df = df[df['shot_outcome'] == 'Goal']
len(filter_df[filter_df['shot_traffic'] == 0])
len(filter_df[filter_df['shot_traffic'] == 1])
# Out:
# 15

# %%
fig, ax = plt.subplots()
df['shot_type'].value_counts().plot(ax=ax, kind='bar')
plt.xlabel('Shot type')
plt.ylabel('Frequency of Occurence')
# Out:
# Text(0, 0.5, 'Frequency of Occurence')

# %%
fig, ax = plt.subplots()
df['shot_onetimer'].value_counts().plot(ax=ax, kind='bar')
plt.xlabel('Shot is one timer')
plt.ylabel('Frequency of Occurence')
# Out:
# Text(0, 0.5, 'Frequency of Occurence')

# %%
fig, ax = plt.subplots()
df['shot_traffic'].value_counts().plot(ax=ax, kind='bar')
plt.xlabel('Shot has traffic')
plt.ylabel('Frequency of Occurence')
# Out:
# Text(0, 0.5, 'Frequency of Occurence')

# %% [markdown]
# ## Making predictive model for determining goals

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
rfc = RandomForestClassifier(random_state=12)

# %%
y = df['shot_outcome'] == 'Goal'
y = y.map({False: 'No_goal', True: 'goal'})
X = df.drop(columns=['shot_outcome'])

# %%
X.columns
# Out:
# Index(['game_date', 'home_team', 'away_team', 'period', 'game_seconds',
#        'time_since_pass', 'home_team_goals', 'away_team_goals', 'team',
#        'game_state', 'passer', 'shooter', 'pass_x', 'pass_y', 'rec_x', 'rec_y',
#        'shot_x', 'shot_y', 'shot_type', 'shot_traffic', 'shot_onetimer',
#        'pass_dist', 'pass_angle', 'shooter_dist', 'shot_dist', 'shot_angle'],
#       dtype='object')

# %%
dropped_columns = ['game_date', 'home_team', 'away_team', 'period', 'pass_x', 'pass_y', 'rec_x', 'rec_y', 'game_seconds']

# %%
X = X.drop(columns=dropped_columns)

# %%
X
# Out:
#       time_since_pass  home_team_goals  away_team_goals                 team  \
# 0                   1                0                0  Minnesota Whitecaps
# 1                   2                0                0         Boston Pride
# 2                   0                0                0  Minnesota Whitecaps
# 3                   1                0                0         Boston Pride
# 4                   2                0                0         Boston Pride
# ...               ...              ...              ...                  ...
# 1011                1                1                7       Buffalo Beauts
# 1012                2                1                7       Buffalo Beauts
# 1013                1                1                7         Boston Pride
# 1014                0                1                7         Boston Pride
# 1015                0                1                7         Boston Pride
#
# ...

# %%
dummies_columns = ['team','passer','shooter', 'shot_type', 'game_state']

# %%
X_dummies = pd.get_dummies(X, prefix_sep='-', columns = dummies_columns)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.33, random_state=42)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=12)

# %%
rfc.predict(X_test)
# Out:
# array(['No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
#        'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal', 'No_goal',
# ...

# %% [markdown]
# ## We predict everything is not a goal. This isn't effective
#
# ## First going to use RFE which is a way to recursively locate the most important features in our model by taking the feature importances and continuing to decrease the size of the data samples to be smaller and smaller.

# %%
rfe = RFE(estimator=rfc, n_features_to_select=25, step=1)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(random_state=12), n_features_to_select=25)

# %%
rfe.ranking_
# Out:
# array([  1,   1,   1,   1,   1,   2,   1,   1,   1,   1,   1,   1,  31,
#         36,  44,  41,  42,  26, 163, 119,   3,  27, 120, 146, 107,  58,
#         50, 148, 144, 139,  47, 103, 185, 106, 186, 156,  22,  88, 141,
#        136, 180, 125, 188,  89,  34,  55, 149,  30, 121, 122, 181, 114,
#        172, 170, 202,  11,  71,  96,  93,  29,  82, 128, 195, 105,  15,
#          1, 115, 171, 123,  32,  64, 220, 209,  21,  20, 158, 176, 110,
#        162, 118,  84, 221,  62,  78,  68, 175,   6, 169, 222, 133, 183,
#         56,  13,  12, 126, 182, 161,   8, 145, 173, 104, 179,  60, 217,
#        216, 219, 204,  79,  74, 191,  19,   1, 142, 199, 207,  28, 213,
#        203,  59,  24,  53, 184,  17,  48,  14, 206, 200,  54,  70, 189,
#          1, 187, 116,   5,  81, 140, 153,  40,  99, 192, 138, 150, 159,
#         23,  69, 168, 137, 112,  94, 165,  10,  49, 108, 131, 101, 215,
#        157,  98, 102,  95, 223, 129,   1, 100,  43, 135,  52, 130,  75,
# ...

# %%
support = rfe.support_
feature_names = X_train.columns
feature_names[support]
# Out:
# Index(['time_since_pass', 'home_team_goals', 'away_team_goals', 'shot_x',
#        'shot_y', 'shot_onetimer', 'pass_dist', 'pass_angle', 'shooter_dist',
#        'shot_dist', 'shot_angle', 'passer-Kelly Babstock',
#        'passer-Shiann Darkangelo', 'shooter-Amanda Conway',
#        'shooter-Jillian Dempsey', 'shooter-Kristin Lewicki',
#        'shooter-Leila Kilduff', 'shooter-Mallory Souliotis',
#        'shooter-Taylor Woods', 'shot_type-Deflection', 'shot_type-Snapshot',
#        'shot_type-Wristshot', 'game_state-5v3', 'game_state-5v4',
#        'game_state-5v5'],
#       dtype='object')

# %%
from imblearn.over_sampling import SMOTE

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_train, rfe.predict(X_train))
# Out:
# array([[654,   0],
#        [  0,  26]])

# %%
confusion_matrix(y_test, rfe.predict(X_test))
# Out:
# array([[322,   1],
#        [ 13,   0]])

# %%
rfe = RFE(estimator=rfc, n_features_to_select=7, step=1)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(random_state=12), n_features_to_select=7)

# %%
support = rfe.support_
feature_names = X_train.columns
feature_names[support]
# Out:
# Index(['shot_x', 'shot_y', 'pass_dist', 'pass_angle', 'shooter_dist',
#        'shot_dist', 'shot_angle'],
#       dtype='object')

# %%
confusion_matrix(y_train, rfe.predict(X_train))
# Out:
# array([[654,   0],
#        [  0,  26]])

# %%
confusion_matrix(y_test, rfe.predict(X_test))
# Out:
# array([[323,   0],
#        [ 13,   0]])

# %% [markdown]
# # December 25, doing some undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
mean_class_size = int(pd.Series(y_train).value_counts().sum()/30)

# %%
mean_class_size
# Out:
# 22

# %%
ratio={'No_goal': mean_class_size,
      'goal': mean_class_size}

# %%
y_train = y_train.map({'No_goal': 0, 'goal':1})

# %%
X_train
# Out:
#      time_since_pass  home_team_goals  away_team_goals  shot_x  shot_y  \
# 567                2                0                1     137      53
# 806                3                2                2     157      46
# 886                1                6                0     148      14
# 656                7                2                2     154       4
# 664                2                2                3     132      22
# ..               ...              ...              ...     ...     ...
# 106                2                1                1     155       8
# 270                5                1                2     160      17
# 860                0                1                0     179      53
# 435                1                0                1     144      32
# 102                1                0                1     168      57
#
#      shot_traffic  shot_onetimer  pass_dist  pass_angle  shooter_dist  ...  \
# ...

# %%
rus = RandomUnderSampler(random_state=12)

# %%
X_train_rus, y_train_rus = rus.fit_sample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-e0925cecb1f4> in <module>()
# ----> 1 X_train_rus, y_train_rus = rus.fit_sample(X_train, y_train)
#
# AttributeError: 'RandomUnderSampler' object has no attribute 'fit_sample'

# %%
import imblearn; imblearn.show_versions(github=True)

# %%
# !pip install --upgrade scikit-learn
# !pip install --upgrade imblearn

# %%
# Class count
count_class_no_goal, count_class_goal = y_train.value_counts()

# Divide by class
df_class_0 = y_train[y_train == 'No_goal'] # 0 is no goal
df_class_1 = y_train[y_train == 'goal'] # 1 is goal

# %%
df_class_0_under = df_class_0.sample(count_class_goal)
df_test_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_test_under.value_counts())

df_test_under.value_counts().plot(kind='bar', title='Count (target)');

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(ratio='minority')
X_sm, y_sm = smote.fit_sample(X_train, y_train)

plot_2d_space(X_sm, y_sm, 'SMOTE over-sampling')

# %% [markdown]
# # February 26, 2021-Binary classification for shot's on goal vs. missed or blocked

# %%
df.head()
# Out:
#     game_date            home_team     away_team  period  game_seconds  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1            53
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1            86
# 2  2021-01-23  Minnesota Whitecaps  Boston Pride       1           190
# 3  2021-01-23  Minnesota Whitecaps  Boston Pride       1           222
# 4  2021-01-23  Minnesota Whitecaps  Boston Pride       1           316
#
#    time_since_pass  home_team_goals  away_team_goals                 team  \
# 0                1                0                0  Minnesota Whitecaps
# 1                2                0                0         Boston Pride
# 2                0                0                0  Minnesota Whitecaps
# 3                1                0                0         Boston Pride
# 4                2                0                0         Boston Pride
#
#   game_state  ... shot_y shot_type  shot_outcome  shot_traffic  shot_onetimer  \
# ...

# %%
df['shot_outcome'].value_counts()
# Out:
# On Net     433
# Blocked    305
# Missed     239
# Goal        39
# Name: shot_outcome, dtype: int64

# %%
plt.scatter(df.pass_dist[0:100], df.time_since_pass[0:100])
for i, txt in enumerate(df['shot_outcome']):
    if df['shot_outcome'][i] == 'Missed':
        plt.scatter(df.shooter_dist[i], df.time_since_pass[i])
        plt.annotate(txt, (df.shooter_dist[i], df.time_since_pass[i]))
    if i >100:
        break
plt.xlabel('Shot Distance (from net)')
plt.ylabel('Time since pass (s)')
# Out:
# Text(0, 0.5, 'Time since pass (s)')

# %% [markdown]
# ## Create our case for finding which of the items turned into a Goal or a shot on net.

# %%
y = df['shot_outcome'].str.contains('Goal|On Net')

# %%
y.value_counts()
# Out:
# False    544
# True     472
# Name: shot_outcome, dtype: int64

# %%
X = df.drop(columns=['shot_outcome'])
dropped_columns = ['game_date']
X = X.drop(columns=dropped_columns)

# %%
dummies_columns = ['team','passer','shooter', 'shot_type', 'game_state', 'home_team', 'away_team']
X_dummies = pd.get_dummies(X, prefix_sep='-', columns = dummies_columns)

# %%
X_dummies.head(3)
# Out:
#    period  game_seconds  time_since_pass  home_team_goals  away_team_goals  \
# 0       1            53                1                0                0
# 1       1            86                2                0                0
# 2       1           190                0                0                0
#
#    pass_x  pass_y  rec_x  rec_y  shot_x  ...  home_team-Connecticut Whale  \
# 0     168      75    161     71     167  ...                            0
# 1     135      33    168     11     175  ...                            0
# 2     199      32    180     37     181  ...                            0
#
#    home_team-Metropolitan Riveters  home_team-Minnesota Whitecaps  \
# 0                                0                              1
# 1                                0                              1
# 2                                0                              1
#
#    home_team-Toronto Six  away_team-Boston Pride  away_team-Buffalo Beauts  \
# ...

# %%
rfc = RandomForestClassifier(random_state=12)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.33, random_state=42)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=12)

# %%
rfc.predict(X_test)[0:10]
# Out:
# array([ True, False,  True, False,  True,  True,  True, False,  True,
#        False])

# %%
len(X_test)
# Out:
# 336

# %%
confusion_matrix(y_test, rfc.predict(X_test))
# Out:
# array([[134,  41],
#        [ 78,  83]])

# %%
precision_score(y_test, rfc.predict(X_test))
# Out:
# 0.6693548387096774

# %%
recall_score(y_test, rfc.predict(X_test))
# Out:
# 0.515527950310559

# %%
# Stat's with a basic random forest classifier using all possible information to determine if it will be a shot on net or not.

# %%
rfe = RFE(estimator=rfc, n_features_to_select=25, step=1)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(random_state=12), n_features_to_select=25)

# %%
support = rfe.support_
feature_names = X_train.columns
feature_names[support]
# Out:
# Index(['period', 'game_seconds', 'time_since_pass', 'home_team_goals',
#        'away_team_goals', 'pass_x', 'pass_y', 'rec_x', 'rec_y', 'shot_x',
#        'shot_y', 'shot_traffic', 'pass_dist', 'pass_angle', 'shooter_dist',
#        'shot_dist', 'shot_angle', 'team-Boston Pride', 'shot_type-Fan',
#        'shot_type-Snapshot', 'shot_type-Wristshot', 'game_state-5v4',
#        'home_team-Metropolitan Riveters', 'away_team-Boston Pride',
#        'away_team-Minnesota Whitecaps'],
#       dtype='object')

# %%
rfe.predict(X_test)[0:10]
# Out:
# array([ True, False,  True, False,  True,  True,  True, False, False,
#        False])

# %%
confusion_matrix(y_test, rfe.predict(X_test))
# Out:
# array([[132,  43],
#        [ 70,  91]])

# %%
precision_score(y_test, rfe.predict(X_test))
# Out:
# 0.6791044776119403

# %%
recall_score(y_test, rfe.predict(X_test))
# Out:
# 0.5652173913043478

# %% [markdown]
# ## small improvement to by including 25 features over the total original factors.

# %%
rfe = RFE(estimator=rfc, n_features_to_select=20, step=1)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=RandomForestClassifier(random_state=12), n_features_to_select=20)

# %%
rfe.support_[0:100]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
support = rfe.support_
feature_names = X_train.columns
feature_names[support]
# Out:
# Index(['period', 'game_seconds', 'time_since_pass', 'home_team_goals',
#        'away_team_goals', 'pass_x', 'pass_y', 'rec_x', 'rec_y', 'shot_x',
#        'shot_y', 'shot_traffic', 'pass_dist', 'pass_angle', 'shooter_dist',
#        'shot_dist', 'shot_angle', 'shot_type-Fan', 'shot_type-Wristshot',
#        'home_team-Metropolitan Riveters'],
#       dtype='object')

# %%
confusion_matrix(y_test, rfe.predict(X_test))
# Out:
# array([[129,  46],
#        [ 82,  79]])

# %%
precision_score(y_test, rfe.predict(X_test))
# Out:
# 0.632

# %%
recall_score(y_test, rfe.predict(X_test))
# Out:
# 0.4906832298136646

# %% [markdown]
# ## I want to try and do pca to do dimensionality reduction w/ vectors

# %%
top_random_forest_features = pd.Series(rfc.feature_importances_.round(3)).sort_values(ascending=False)[0:20]

# %%
top_random_forest_features
# Out:
# 17     0.064
# 9      0.058
# 16     0.055
# 7      0.051
# 15     0.046
# 5      0.043
# 14     0.041
# 1      0.041
# 13     0.040
# 6      0.037
# 10     0.037
# 8      0.034
# 11     0.033
# 2      0.022
# 3      0.020
# 4      0.015
# 0      0.014
# 249    0.008
# 242    0.008
# 240    0.008
# dtype: float64

# %%
importances = top_random_forest_features

# %%
features = X_test.columns[0:15]

# %%
df_feature_importance = pd.DataFrame(rfc.feature_importances_, index = X_test.columns )

# %%
df_feature_importance.to_csv('df_feature_importances.csv')

# %%
importances = rfc.feature_importances_[0:15]
indices = np.argsort(importances)

# %%
feature_names = X_train.columns
feature_names[top_random_forest_features.axes]
# Out:
# /Users/davescott/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py:4114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
# Index(['shot_angle', 'shot_x', 'shot_dist', 'rec_x', 'shooter_dist', 'pass_x',
#        'pass_angle', 'game_seconds', 'pass_dist', 'pass_y', 'shot_y', 'rec_y',
#        'shot_traffic', 'time_since_pass', 'home_team_goals', 'away_team_goals',
#        'period', 'game_state-5v4', 'shot_type-Snapshot', 'shot_type-Fan'],
#       dtype='object')

# %%
plt.title('Shot Classification Model Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='turquoise', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.gca().xaxis.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# # Use a logistic regressor

# %% [markdown]
# ### scale data

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LogisticRegression(random_state=13)
lr.fit(X_train_scaled, y_train)

# %%
confusion_matrix(y_test, lr.predict(X_test_scaled))

# %%
precision_score(y_test, lr.predict(X_test_scaled))

# %%
recall_score(y_test, lr.predict(X_test_scaled))

# %%
rfe_lr = RFE(estimator=lr, n_features_to_select=7, step=1)
rfe_lr.fit(X_train_scaled, y_train)

# %%
support = rfe_lr.support_
feature_names = X_train.columns
feature_names[support]

# %%
confusion_matrix(y_test, rfe_lr.predict(X_test_scaled))

# %%
precision_score(y_test, rfe_lr.predict(X_test_scaled))

# %%
recall_score(y_test, rfe_lr.predict(X_test_scaled))

# %% [markdown]
# ## Support vector machine

# %%
svc = LinearSVC(penalty='l2', loss='hinge', random_state=8)
svc.fit(X_train_scaled, y_train)

# %%
confusion_matrix(y_test, svc.predict(X_test_scaled))

# %%
precision_score(y_test, svc.predict(X_test_scaled))

# %%
recall_score(y_test, svc.predict(X_test_scaled))

# %%
rfe_svc = RFE(estimator=svc, n_features_to_select=7, step=1)
rfe_svc.fit(X_train_scaled, y_train)

# %%
confusion_matrix(y_test, rfe_svc.predict(X_test_scaled))

# %%
precision_score(y_test, rfe_svc.predict(X_test_scaled))

# %%
recall_score(y_test, rfe_svc.predict(X_test_scaled))

# %%
estimators = [('rf', RandomForestClassifier( random_state=42)),
              ('svr', make_pipeline(StandardScaler(), LinearSVC(random_state=42))),
              ('lr', make_pipeline(StandardScaler(), LogisticRegression(random_state=42)))]

# %%
clf = StackingClassifier(estimators=estimators,
                         final_estimator=GradientBoostingClassifier())

# %%
clf.fit(X_train, y_train)

# %%
confusion_matrix(y_test, clf.predict(X_test))

# %%
precision_score(y_test, clf.predict(X_test))

# %%
recall_score(y_test, clf.predict(X_test))
